# %% [markdown]
# Notebook for reprocucing the nTABS correlation results from J. Chem. Inf. Model. 2024, 64, 20, 7917–7924

# %%
import pandas as pd
from plots import PlotNTabsCorrelationAnalysis
# Out:
# /tmp/ipykernel_2516754/1620710141.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dat = pd.read_csv("../Data/nTABS/Output/ntabsNconfsout.csv")
## filtering for the conformer generation runs that did not finish within 120 hours
dat = dat[dat.nconfsout > 0]

# %%
PlotNTabsCorrelationAnalysis(dat);
